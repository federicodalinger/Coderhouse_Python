# %%
# Ejercicio 1) Cargamos los valores e imprimimos el tipo de dato individual:

dato_1="Hola Mundo"
dato_2=[1, 10, 100]
dato_3=-25
dato_4=(8, 100, -12)
dato_5=1.167
dato_6=["Hola", "Mundo"]
dato_7=' '
dato_8=(1, -5, "Hola!")

print(f"""
      El tipo de dato, del dato_1 es: {type(dato_1)}
      El tipo de dato, del dato_2 es: {type(dato_2)}
      El tipo de dato, del dato_3 es: {type(dato_3)}
      El tipo de dato, del dato_4 es: {type(dato_4)}
      El tipo de dato, del dato_5 es: {type(dato_5)}
      El tipo de dato, del dato_6 es: {type(dato_6)}
      El tipo de dato, del dato_7 es: {type(dato_7)}
      El tipo de dato, del dato_8 es: {type(dato_8)}  
      """)
# Out:
#       El tipo de dato, del dato_1 es: <class 'str'>
#       El tipo de dato, del dato_2 es: <class 'list'>
#       El tipo de dato, del dato_3 es: <class 'int'>
#       El tipo de dato, del dato_4 es: <class 'tuple'>
#       El tipo de dato, del dato_5 es: <class 'float'>
#       El tipo de dato, del dato_6 es: <class 'list'>
#       El tipo de dato, del dato_7 es: <class 'str'>
#       El tipo de dato, del dato_8 es: <class 'tuple'>

# %%
# Ejercicio 2) Cargamos los datos y hacemos las operaciones:

a=10
b=-5
c="Hola"
d=[1, 2, 3]
e=(4, 5, 6)

print(f"""
      print(a * 5): {a*5}
      print(a - b): {a - b}
      print(c + "Mundo"): {c + "Mundo"}
      print(c * 2): {c * 2}
      print(c[-1]): {c[-1]}
      print(c[1:]): {c[1:]}
      print(d + d): {d + d}
      print(e[1]): {e[1]}  
      print(e+(7,8,9)): {e+(7,8,9)}  
      """)
# Out:
#       print(a * 5): 50
#       print(a - b): 15
#       print(c + "Mundo"): HolaMundo
#       print(c * 2): HolaHola
#       print(c[-1]): a
#       print(c[1:]): ola
#       print(d + d): [1, 2, 3, 1, 2, 3]
#       print(e[1]): 5
#       print(e+(7,8,9)): (4, 5, 6, 7, 8, 9)

# %%
# Ejercicio 3) Cargamos los datos y hacemos las operaciones:

numero_1 = 9
numero_2 = 3
numero_3 = 7

media=(numero_1 + numero_2 + numero_3) / 3

print("La nota media es", media)
print(f"La nota media es {media:.2f}")
# Out:
# La nota media es 6.333333333333333
# La nota media es 6.33

# %%
# Ejercicio 4)

# Defino los % que cuentan de cada nota para la nota final:

porcent_nota_1=15
porcent_nota_2=35
porcent_nota_3=50

# Creo variable para cada nota a ingresar (indico flot porque puede ser decimal, ej: 9.5):

nota_1=float(input(f"Ingrese la 1er nota: "))
nota_2=float(input(f"Ingrese la 2da nota: "))
nota_3=float(input(f"Ingrese la 3er nota: "))

# Creo variable de la nota final (aplicando operacion suma, multiplicacion y division):

nota_final=(porcent_nota_1*nota_1+porcent_nota_2*nota_2+porcent_nota_3*nota_3)/100
7
# Muestro la nota final del alumno en cuestion, segun sus notas 1 y 2 ingresadas.
# Uso ":.2f" para limitar la cantidad de decimales a mostrar, sin redondear:

print(f"La nota final es: {nota_final:.2f}")
# Out:
# Ingrese la 1er nota: 10
# Ingrese la 2da nota: 7
# Ingrese la 3er nota: 4
# La nota final es: 5.95

# %%
# Ejercicio 5)

# Defino la matriz de origen:

matriz = [ [1, 5, 1],
           [2, 1, 2],
           [3, 0, 1],
           [1, 4, 4] ]

# Agrego en la ultima posicion, de cada sublista, la suma de la sublista:

matriz[0].append(sum(matriz[0]))
matriz[1].append(sum(matriz[1]))
matriz[2].append(sum(matriz[2]))
matriz[3].append(sum(matriz[3]))

# Muestro la lista resultante:

print (matriz)
# Out:
# [[1, 5, 1, 7], [2, 1, 2, 5], [3, 0, 1, 4], [1, 4, 4, 9]]
